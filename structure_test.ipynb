# %%
import latools as lt
# %matplotlib inline

# %%
d = lt.analyse('latools/resources/test_data/')
# Out:
# 4 Analysis Files Loaded:
# 1 standards, 3 samples
# Analytes: Mg24 Mg25 Al27 Ca43 Ca44 Mn55 Sr88 Ba137 Ba138

# %%
s = d.data_dict['STD-3']

# %%
d.data_dict['STD-3'].tplot()
# Out:
# /Users/oscarbranson/anaconda/envs/py3/lib/python3.5/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /Users/oscarbranson/anaconda/envs/py3/lib/python3.5/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):

# %%
d.find_expcoef(trimlim=0.2,plot=True)
# Out:
# -------------------------------------
# Exponential Decay Coefficient: -2.98
# -------------------------------------

# %%
d.despike(exponent=-2.98)

# %%
d.autorange()

# %%
d.bkgcorrect()

# %%
d.ratio()

# %%
d.calibrate()
# Out:
# SRM range files already exist. Do you want to overwrite them (old files will be lost)? [Y/n]:
# SRM range files already exist in 'latools/resources/test_data//params/test_data.calibdat'. Do you want to overwrite them (old files will be lost)? [Y/n]:

# %%
fig, ax = d.crossplot()

# %%
d.stat_samples(filt=False)

# %%
s = d.data_dict['STD-3']

# %%
x = np.linspace(0, 6 * np.pi, 90)
y = np.sin(x)
ms = s.findmins(x, y)

# %%
g = s.fastgrad(s.rawdata['Ca43'])

# %%
plt.plot(g)

# %%
d.data_dict['A1-1'].tplot(scale='log')

# %%
d = d.data_dict['A1-1'].focus

# %%
import pickle

# %%
f = open('sam.pkl', 'wb')
pickle.dump(d, f)
f.close()

# %%
with open('sam.txt', 'wb') as f:
    f.writelines('{}:{}\n'.format(k,v) for k, v in d.items())
